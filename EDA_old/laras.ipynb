# %%
import csv
import pandas as pd

import pandas as pd
import altair as alt

bussiness_licences = "business-licences-hackathon.csv"
file = open(bussiness_licences, "r")
reader = pd.read_csv(file, sep=';')
# Out:
# /Users/larahabashy/Downloads/miniconda3/envs/532env/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_no_nan = reader.dropna(subset=['BusinessName'])
businesses_names = df_no_nan[~df_no_nan.BusinessName.str.contains('(', regex=False)].BusinessName.unique()

business_trade_names = df_no_nan[df_no_nan['BusinessName'].str.contains('(', regex=False)]["BusinessTradeName"].unique()

# %%
df_no_nan.head()
# Out:
#    FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 0          14     2180123     14-160030                      0
# 1          14     2180373     14-160220                      0
# 2          14     2180374     14-160221                      0
# 3          14     2180382     14-160226                      0
# 4          13     2180556     13-449866                      0
#
#                          BusinessName                BusinessTradeName  \
# 0         Golden Trim Enterprises Inc                        Floorhaus
# 1               Tamton Networking Inc                 Tam Ton Training
# 2  Jack W Chow Insurance Services Ltd                              NaN
# 3                  Time Education Inc                              NaN
# 4                        (Maiko Sato)  Nankurunaisa Education Services
#
#       Status                 IssuedDate ExpiredDate  \
# 0     Issued  2013-12-05T19:08:53-05:00  2014-12-31
# 1     Issued  2014-02-26T16:08:59-05:00  2014-12-31
# 2     Issued  2013-12-06T11:57:32-05:00  2014-12-31
# 3  Cancelled                        NaN         NaN
# 4     Issued  2013-12-17T16:18:45-05:00  2013-12-31
#
#                       BusinessType  ...        Street       City Province  \
# 0  Wholesale Dealer w/ Anc. Retail  ...      W 3RD AV  Vancouver       BC
# 1                      Instruction  ...   W PENDER ST  Vancouver       BC
# 2                           Office  ...   E PENDER ST  Vancouver       BC
# 3                      Educational  ...  GRANVILLE ST  Vancouver       BC
# 4                Referral Services  ...           NaN  Vancouver       BC
#
#   Country PostalCode       LocalArea NumberofEmployees FeePaid  \
# 0      CA    V5Y 1G1  Mount Pleasant               4.0   262.0
# 1      CA    V6B 6N9        Downtown               0.0   130.0
# 2      CA    V6A 1S9        Downtown              10.0   130.0
# 3      CA    V6M 4J7      Kerrisdale               2.0    51.0
# 4      CA        NaN      Riley Park               1.0    62.0
#
#                  ExtractDate  \
# 0  2019-07-21T16:49:13-04:00
# 1  2019-07-21T16:49:13-04:00
# 2  2019-07-21T16:49:13-04:00
# 3  2019-07-21T16:49:13-04:00
# 4  2019-07-21T16:49:13-04:00
#
#                                                 Geom
# 0  {"type": "Point", "coordinates": [-123.1098925...
# 1  {"type": "Point", "coordinates": [-123.1067518...
# 2  {"type": "Point", "coordinates": [-123.1040791...
# 3  {"type": "Point", "coordinates": [-123.1401383...
# 4                                                NaN
#
# [5 rows x 24 columns]

# %%
dat = df_no_nan.query("BusinessName=='Tamton Networking Inc'").sort_values(by=['IssuedDate']).dropna()
dat = dat.reset_index()
dat
# Out:
#     index  FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 0  212542          13     2100546     13-429330                      0
# 1  182926          14     2180371     14-160219                      0
# 2       1          14     2180373     14-160220                      0
# 3   34653          15     2372970     15-143246                      0
# 4  181386          15     2354164     15-124452                      0
#
#             BusinessName BusinessTradeName  Status                 IssuedDate  \
# 0  Tamton Networking Inc   Tamton Training  Issued  2013-10-07T16:44:03-04:00
# 1  Tamton Networking Inc  Tam Ton Training  Issued  2014-02-26T16:08:32-05:00
# 2  Tamton Networking Inc  Tam Ton Training  Issued  2014-02-26T16:08:59-05:00
# 3  Tamton Networking Inc  Tam Ton Training  Issued  2015-01-22T18:56:28-05:00
# 4  Tamton Networking Inc  Tam Ton Training  Issued  2015-01-22T18:56:29-05:00
#
#   ExpiredDate  ...       Street       City Province Country PostalCode  \
# 0  2013-12-31  ...  RICHARDS ST  Vancouver       BC      CA    V6B 2Z4
# 1  2014-12-31  ...  W PENDER ST  Vancouver       BC      CA    V6B 6N9
# 2  2014-12-31  ...  W PENDER ST  Vancouver       BC      CA    V6B 6N9
# 3  2015-12-31  ...  W PENDER ST  Vancouver       BC      CA    V6B 6N9
# 4  2015-12-31  ...  W PENDER ST  Vancouver       BC      CA    V6B 6N9
#
#   LocalArea NumberofEmployees FeePaid                ExtractDate  \
# 0  Downtown               0.0    82.0  2019-07-21T16:49:09-04:00
# 1  Downtown               0.0   130.0  2019-07-21T16:49:13-04:00
# 2  Downtown               0.0   130.0  2019-07-21T16:49:13-04:00
# 3  Downtown               4.0   173.0  2019-07-21T16:49:16-04:00
# 4  Downtown               4.0   173.0  2019-07-21T16:49:15-04:00
#
#                                                 Geom
# 0  {"type": "Point", "coordinates": [-123.1119263...
# 1  {"type": "Point", "coordinates": [-123.1067518...
# 2  {"type": "Point", "coordinates": [-123.1067518...
# 3  {"type": "Point", "coordinates": [-123.1067518...
# 4  {"type": "Point", "coordinates": [-123.1067518...
#
# [5 rows x 25 columns]

# %%
chart1 = alt.Chart(dat).mark_circle().encode(
    x='LicenceNumber:N',y='IssuedDate', color='Status'
)
chart2 = alt.Chart(dat).mark_circle().encode(
    x='LicenceNumber:N',y='ExpiredDate', color='Status'
)
chart1 #add tooltip
# Out:
# alt.Chart(...)
