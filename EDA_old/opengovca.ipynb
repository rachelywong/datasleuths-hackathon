# %%
import csv
import pandas as pd

import requests
from bs4 import BeautifulSoup, SoupStrainer
import re
import numpy as np
import json
bussiness_licences = "business-licences-hackathon.csv"
file = open(bussiness_licences, "r")
reader = pd.read_csv(file, sep=';')
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
reader[reader['Street'].isna()]
# Out:
#         FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 4               13     2180556     13-449866                      0
# 10              14     2180667     14-127846                      1
# 11              13     2180702     13-449988                      0
# 15              14     2181452     14-160895                      0
# 16              14     2181480     14-160900                      0
# ...            ...         ...           ...                    ...
# 569013          21     3729689     21-147173                      0
# 569014          21     3729693     21-147177                      0
# 569019          21     3729705     21-147189                      0
# 569023          21     3729717     21-147201                      0
# 569025          21     3729719     21-147203                      0
#
#                                BusinessName                BusinessTradeName  \
# 4                              (Maiko Sato)  Nankurunaisa Education Services
# 10                     Yee Ha Lau (Yee Lau)                              NaN
# 11                 (Ermilo Martinez Juarez)                 Erma Renovations
# 15      Kamaljit S Khinda (Kamaljit Khinda)                              NaN
# 16              Thomas J Gill (Thomas Gill)         Shore Plumbing & Heating
# ...                                     ...                              ...
# 569013                            (Yue Cao)    Working Crew Home Maintenance
# 569014                          (Jun Zhang)              NewGen Computing Co
# 569019                       1122318 BC Ltd           Roger Appliance Repair
# 569023                        (Jeffrey Liu)         Fraserview Bike Mechanic
# 569025    Tickety-Boo Handyman Services Inc                              NaN
#
#          Status                 IssuedDate ExpiredDate  \
# 4        Issued  2013-12-17T16:18:45-05:00  2013-12-31
# 10       Issued  2013-12-06T18:28:29-05:00  2014-12-31
# 11       Issued  2013-12-06T19:27:46-05:00  2013-12-31
# 15       Issued  2013-12-09T14:19:55-05:00  2014-12-31
# 16       Issued  2013-12-09T15:24:33-05:00  2014-12-31
# ...         ...                        ...         ...
# 569013   Issued  2021-02-08T23:35:36-05:00  2021-12-31
# 569014   Issued  2020-12-29T20:22:33-05:00  2021-12-31
# 569019  Pending                        NaN         NaN
# 569023   Issued  2020-12-05T03:36:00-05:00  2021-12-31
# 569025  Pending                        NaN         NaN
#
#                        BusinessType  ... Street       City Province Country  \
# 4                 Referral Services  ...    NaN  Vancouver       BC      CA
# 10                Multiple Dwelling  ...    NaN  Vancouver       BC      CA
# 11                       Contractor  ...    NaN  Vancouver       BC      CA
# 15      Secondary Suite - Permanent  ...    NaN  Vancouver       BC      CA
# 16         Plumber & Gas Contractor  ...    NaN  Vancouver       BC      CA
# ...                             ...  ...    ...        ...      ...     ...
# 569013  Repair/ Service/Maintenance  ...    NaN  Vancouver       BC      CA
# 569014  Repair/ Service/Maintenance  ...    NaN  Vancouver       BC      CA
# 569019  Repair/ Service/Maintenance  ...    NaN  Vancouver       BC      CA
# 569023  Repair/ Service/Maintenance  ...    NaN  Vancouver       BC      CA
# 569025  Repair/ Service/Maintenance  ...    NaN  Vancouver       BC      CA
#
#        PostalCode                 LocalArea NumberofEmployees FeePaid  \
# 4             NaN                Riley Park               1.0    62.0
# 10            NaN                  Fairview               0.0    10.0
# 11            NaN                  West End               1.0    63.0
# 15            NaN                Riley Park               0.0   126.0
# 16            NaN           West Point Grey               2.0   130.0
# ...           ...                       ...               ...     ...
# 569013        NaN  Kensington-Cedar Cottage               2.0   195.0
# 569014        NaN       Renfrew-Collingwood               1.0   155.0
# 569019        NaN                  Oakridge               1.0     NaN
# 569023        NaN                 Killarney               0.0   233.0
# 569025        NaN                  Fairview               1.0     NaN
#
#                       ExtractDate Geom
# 4       2019-07-21T16:49:13-04:00  NaN
# 10      2019-07-21T16:49:13-04:00  NaN
# 11      2019-07-21T16:49:13-04:00  NaN
# 15      2019-07-21T16:49:13-04:00  NaN
# 16      2019-07-21T16:49:13-04:00  NaN
# ...                           ...  ...
# 569013  2021-02-22T03:08:55-05:00  NaN
# 569014  2021-02-22T03:08:55-05:00  NaN
# 569019  2021-02-22T03:08:55-05:00  NaN
# 569023  2021-02-22T03:08:55-05:00  NaN
# 569025  2021-02-22T03:08:55-05:00  NaN
#
# [255656 rows x 24 columns]

# %%
reader.query('LicenceNumber == "21-123107"')
# Out:
#         FOLDERYEAR  LicenceRSN LicenceNumber  LicenceRevisionNumber  \
# 550393          21     3705623     21-123107                      0
#
#                  BusinessName BusinessTradeName  Status  \
# 550393  (Mohammed Al-Mehaisi)               NaN  Issued
#
#                        IssuedDate ExpiredDate       BusinessType  ...  \
# 550393  2021-02-03T14:10:35-05:00  2021-12-31  Health and Beauty  ...
#
#           Street       City Province Country PostalCode LocalArea  \
# 550393  DAVIE ST  Vancouver       BC      CA    V6E 1H3  West End
#
#        NumberofEmployees FeePaid                ExtractDate  \
# 550393               1.0   323.0  2021-02-22T03:08:53-05:00
#
#                                                      Geom
# 550393  {"type": "Point", "coordinates": [-123.1309636...
#
# [1 rows x 24 columns]

# %%
reader.query("BusinessName == 'AMAZON DEVELOPMENT CENTRE CANADA ULC'")
# Out:
# Empty DataFrame
# Columns: [FOLDERYEAR, LicenceRSN, LicenceNumber, LicenceRevisionNumber, BusinessName, BusinessTradeName, Status, IssuedDate, ExpiredDate, BusinessType, BusinessSubType, Unit, UnitType, House, Street, City, Province, Country, PostalCode, LocalArea, NumberofEmployees, FeePaid, ExtractDate, Geom]
# Index: []
#
# [0 rows x 24 columns]

# %%
reader

# %%
# 35050 Business name is peoples names in brackets which are likely
# not to have results in canadabusinessregistries
df_no_nan = reader.dropna(subset=['BusinessName'])
businesses_names = df_no_nan[~df_no_nan.BusinessName.str.contains('(', regex=False)].BusinessName.unique()

# 35050 Business name is peoples names in brackets which are likely
# not to have results in canadabusinessregistries 
# so I am getting their business trade name instead. 
business_trade_names = df_no_nan[df_no_nan['BusinessName'].str.contains('(', regex=False)]["BusinessTradeName"].unique()
